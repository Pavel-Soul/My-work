# %%
import imaplib
 
mail = imaplib.IMAP4_SSL('imap.yandex.ru')
mail.login('danila-763@yandex.ru', 'jfxqvjfowmukhwwg')
# Out:
# ('OK', [b'LOGIN Completed.'])

# %%
import base64

# %%
mail.select('&BCMEPQQ4BDIENQRA-|&BCMERwQ4BEIENQQ7BE8-')
# Out:
# ('OK', [b'253'])

# %%
mas = mail.list()[1]

# %%
m = "noreply@taxcom.ru"
result, data = mail.search(None, 'FROM', m)
 
ids = data[0]
id_list = ids.split()
latest_email_id = id_list[-1]
 
result, data = mail.fetch(latest_email_id, "(RFC822)")
raw_email = data[0][1]
raw_email_string = raw_email.decode('utf-8')
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# d:\Университет\Второй курс\TVMS\List3\test.ipynb Ячейка 2 line 6
#       <a href='vscode-notebook-cell:/d%3A/%D0%A3%D0%BD%D0%B8%D0%B2%D0%B5%D1%80%D1%81%D0%B8%D1%82%D0%B5%D1%82/%D0%92%D1%82%D0%BE%D1%80%D0%BE%D0%B9%20%D0%BA%D1%83%D1%80%D1%81/TVMS/List3/test.ipynb#W1sZmlsZQ%3D%3D?line=3'>4</a> ids = data[0]
#       <a href='vscode-notebook-cell:/d%3A/%D0%A3%D0%BD%D0%B8%D0%B2%D0%B5%D1%80%D1%81%D0%B8%D1%82%D0%B5%D1%82/%D0%92%D1%82%D0%BE%D1%80%D0%BE%D0%B9%20%D0%BA%D1%83%D1%80%D1%81/TVMS/List3/test.ipynb#W1sZmlsZQ%3D%3D?line=4'>5</a> id_list = ids.split()
# ----> <a href='vscode-notebook-cell:/d%3A/%D0%A3%D0%BD%D0%B8%D0%B2%D0%B5%D1%80%D1%81%D0%B8%D1%82%D0%B5%D1%82/%D0%92%D1%82%D0%BE%D1%80%D0%BE%D0%B9%20%D0%BA%D1%83%D1%80%D1%81/TVMS/List3/test.ipynb#W1sZmlsZQ%3D%3D?line=5'>6</a> latest_email_id = id_list[-1]
#       <a href='vscode-notebook-cell:/d%3A/%D0%A3%D0%BD%D0%B8%D0%B2%D0%B5%D1%80%D1%81%D0%B8%D1%82%D0%B5%D1%82/%D0%92%D1%82%D0%BE%D1%80%D0%BE%D0%B9%20%D0%BA%D1%83%D1%80%D1%81/TVMS/List3/test.ipynb#W1sZmlsZQ%3D%3D?line=7'>8</a> result, data = mail.fetch(latest_email_id, "(RFC822)")
#       <a href='vscode-notebook-cell:/d%3A/%D0%A3%D0%BD%D0%B8%D0%B2%D0%B5%D1%80%D1%81%D0%B8%D1%82%D0%B5%D1%82/%D0%92%D1%82%D0%BE%D1%80%D0%BE%D0%B9%20%D0%BA%D1%83%D1%80%D1%81/TVMS/List3/test.ipynb#W1sZmlsZQ%3D%3D?line=8'>9</a> raw_email = data[0][1]
#
# IndexError: list index out of range

# %%
raw_email_string
# Out:
# 'Received: from postback19b.mail.yandex.net (postback19b.mail.yandex.net [2a02:6b8:c02:900:1:45:d181:da19])\r\n\tby iswah2ufs3gwepzq.myt.yp-c.yandex.net (notsolitesrv/Yandex) with LMTP id scCyc6CwWY-xMnS71zW\r\n\tfor <danila-763@yandex.ru>; Wed, 27 Sep 2023 10:01:55 +0300\r\nReceived: from mail-nwsmtp-yaback-production-main-40.iva.yp-c.yandex.net (mail-nwsmtp-yaback-production-main-40.iva.yp-c.yandex.net [IPv6:2a02:6b8:c0c:9687:0:640:c242:0])\r\n\tby postback19b.mail.yandex.net (Yandex) with ESMTP id 8E57E5E76B\r\n\tfor <danila-763@yandex.ru>; Wed, 27 Sep 2023 10:01:55 +0300 (MSK)\r\nReceived: from y4u2n6u2fgkf7swt.sas.yp-c.yandex.net (y4u2n6u2fgkf7swt.sas.yp-c.yandex.net [2a02:6b8:c08:281d:0:640:af0e:0])\r\n\tby mail-nwsmtp-yaback-production-main-40.iva.yp-c.yandex.net (yaback/Yandex) with ESMTP id p1KQ7VD9aKo0-gDtu9gUu;\r\n\tWed, 27 Sep 2023 10:01:55 +0300\r\nX-Yandex-Fwd: 1\r\nDKIM-Signature: v=1; a=rsa-sha256; c=relaxed/relaxed; d=yandex.ru; s=mail;\r\n\tt=1695798115; bh=3VHAqEu2bmx3ItYgImp77/eGF/mxKla/J/OCTIz1Voc=;\r\n\th=Subject:List-Unsubscribe:Reply-To:To:List-ID:Message-ID:Date:\r\n\t From;\r\n\tb=QpZVly5NjXFYYYDXB/e2eL/kDv5lr1Y4KSdpreJTV4AcQJyfj1QRIRTzWVBRQDmPr\r\n\t w1MvvNg/wuWOu6e7qD/ozvj3unh/UIhRNQn7Y6ltQJB6VTFy5Xo/RVcqLCJGdmKkKm\r\n\t Omtn5nv5Cd88bwRZOWFlikDF+fzy8B6hwdbO/aAc=\r\nAuthentication-Results: mail-nwsmtp-yaback-production-main-40.iva.yp-c.yandex.net; dkim=pass header.i=@yandex.ru\r\nX-Yandex-Spam: 1\r\nX-Yandex-Uid-Status: 1 362918335\r\nContent-Type: multipart/mixed; boundary="===============0782090902862622719=="\r\nMIME-Version: 1.0\r\nList-ID: <sendr-1198596.yandex.ru>\r\nDate: Wed, 27 Sep 2023 07:01:53 +0000\r\nReply-To: d-sitdikov@yandex-team.ru\r\nTo: danila-763@yandex.ru\r\nFrom: =?utf-8?b?0K/QvdC00LXQutGBINCU0LjQsNC70L7Qs9C4?= <dialogs@yandex.ru>\r\nX-Sendr-Id: L/Q2pRcFh4MVRYUUZNVUFGSklsc05JeTlsTUVNTVd3WmRlM3RwQUhrQmVYWjBlMmNBRG4xaWZFWlVCR0VFQUVSOVJYWUhmaGtBZTNsYQpjbkpwYlVGVFQwZE1mbFZ0VDJaM2UzZ3hGem9GUERnSllCOHlOd2NuRTNZV1Z4d3BDbndJQ1ZVeUd6c0ROZzVUSUdwYU1TSU46MTU1Mzow\r\nX-Sender-Campaign-Type: simple\r\nList-Unsubscribe: https://unsubscribe.yandex.ru/unsubscribe/L/Q2pRcFh4MVRYUUZNVUFGSklsc05JeTlsTUVNTVd3WmRlM3RwQUhrQmVYWjBlMmNBRG4xaWZFWlVCR0VFQUVSOVJYWUhmaGtBZTNsYQpjbkpwYlVGVFQwZE1mbFZ0VDJaM2UzZ3hGem9GUERnSllCOHlOd2NuRTNZV1Z4d3BDbndJQ1ZVeUd6c0ROZzVUSUdwYU1TSU46MTU1Mzow\r\nX-Mailer: YandexSender/0.1\r\nX-Auto-Response-Suppress: All\r\nX-Sender-Account: yandex.speechkit\r\nMessage-ID: <20230927100142.818285.94590.5397.53@cxhqdqp6mguijq2g.sas.yp-c.yandex.net>\r\nSubject: =?utf-8?b?0J/RgNC10LzQuNGPINCQ0LvQuNGB0Ys6INCz0L7Qu9C+0YHQvtCy0LDQvdC40LUg0LfQsCDQu9GD0YfRiNC40Lkg0L3QsNCy0YvQuiDQv9C+INCy0LXRgNGB0LjQuCDRgdC+0L7QsdGJ0LXRgdGC0LLQsCDRgNCw0LfRgNCw0LHQvtGC0YfQuNC60L7Qsg==?=\r\nX-Mailru-Msgtype: <sendr-1198596>\r\nPrecedence: bulk\r\nReturn-Path: sndr.bnc@yandex.ru\r\nX-Yandex-Forward: 5649fe2bafdeff093fb92369b6a551dd\r\n\r\nThis is a multi-part message in MIME format.\r\n\r\n--===============0782090902862622719==\r\nContent-Type: multipart/related; boundary="===============4658157802739815799=="\r\nMIME-Version: 1.0\r\n\r\n--===============4658157802739815799==\r\nContent-Type: multipart/alternative; boundary="===============6479445411493023831=="\r\nMIME-Version: 1.0\r\n\r\n--===============6479445411493023831==\r\nContent-Type: text/html; charset="utf-8"\r\nMIME-Version: 1.0\r\nContent-Transfer-Encoding: base64\r\n\r\\r\nInZpZXdwb3J0IiBjb250ZW50PSJ3a ...

# %%
import email
email_message = email.message_from_string(raw_email_string)
 
print(email_message['To'])
print(email.utils.parseaddr(email_message['From']))
print(email_message['Date'])
print(email_message['Subject'])
print(email_message['Message-Id'])
# Out:
# danila-763@yandex.ru
# ('=?utf-8?b?0K/QvdC00LXQutGBINCU0LjQsNC70L7Qs9C4?=', 'dialogs@yandex.ru')
# Wed, 27 Sep 2023 07:01:53 +0000
# =?utf-8?b?0J/RgNC10LzQuNGPINCQ0LvQuNGB0Ys6INCz0L7Qu9C+0YHQvtCy0LDQvdC40LUg0LfQsCDQu9GD0YfRiNC40Lkg0L3QsNCy0YvQuiDQv9C+INCy0LXRgNGB0LjQuCDRgdC+0L7QsdGJ0LXRgdGC0LLQsCDRgNCw0LfRgNCw0LHQvtGC0YfQuNC60L7Qsg==?=
# <20230927100142.818285.94590.5397.53@cxhqdqp6mguijq2g.sas.yp-c.yandex.net>

# %%
if email_message.is_multipart():
    for payload in email_message.get_payload():
        body = payload.get_payload(decode=True).decode('utf-8')
        print(body)
else:    
    body = email_message.get_payload(decode=True).decode('utf-8')
    print(body)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# d:\Университет\Второй курс\TVMS\List3\test.ipynb Ячейка 5 line 3
#       <a href='vscode-notebook-cell:/d%3A/%D0%A3%D0%BD%D0%B8%D0%B2%D0%B5%D1%80%D1%81%D0%B8%D1%82%D0%B5%D1%82/%D0%92%D1%82%D0%BE%D1%80%D0%BE%D0%B9%20%D0%BA%D1%83%D1%80%D1%81/TVMS/List3/test.ipynb#W4sZmlsZQ%3D%3D?line=0'>1</a> if email_message.is_multipart():
#       <a href='vscode-notebook-cell:/d%3A/%D0%A3%D0%BD%D0%B8%D0%B2%D0%B5%D1%80%D1%81%D0%B8%D1%82%D0%B5%D1%82/%D0%92%D1%82%D0%BE%D1%80%D0%BE%D0%B9%20%D0%BA%D1%83%D1%80%D1%81/TVMS/List3/test.ipynb#W4sZmlsZQ%3D%3D?line=1'>2</a>     for payload in email_message.get_payload():
# ----> <a href='vscode-notebook-cell:/d%3A/%D0%A3%D0%BD%D0%B8%D0%B2%D0%B5%D1%80%D1%81%D0%B8%D1%82%D0%B5%D1%82/%D0%92%D1%82%D0%BE%D1%80%D0%BE%D0%B9%20%D0%BA%D1%83%D1%80%D1%81/TVMS/List3/test.ipynb#W4sZmlsZQ%3D%3D?line=2'>3</a>         body = payload.get_payload(decode=True).decode('utf-8')
#       <a href='vscode-notebook-cell:/d%3A/%D0%A3%D0%BD%D0%B8%D0%B2%D0%B5%D1%80%D1%81%D0%B8%D1%82%D0%B5%D1%82/%D0%92%D1%82%D0%BE%D1%80%D0%BE%D0%B9%20%D0%BA%D1%83%D1%80%D1%81/TVMS/List3/test.ipynb#W4sZmlsZQ%3D%3D?line=3'>4</a>         print(body)
#       <a href='vscode-notebook-cell:/d%3A/%D0%A3%D0%BD%D0%B8%D0%B2%D0%B5%D1%80%D1%81%D0%B8%D1%82%D0%B5%D1%82/%D0%92%D1%82%D0%BE%D1%80%D0%BE%D0%B9%20%D0%BA%D1%83%D1%80%D1%81/TVMS/List3/test.ipynb#W4sZmlsZQ%3D%3D?line=4'>5</a> else:
#
# AttributeError: 'NoneType' object has no attribute 'decode'
