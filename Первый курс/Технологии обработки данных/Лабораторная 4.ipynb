# %%
import pandas as pd
from pathlib import Path
import numpy as np
import xlwings as xw

# %%
dp = Path('./src/tables/recipes_model/')

# %% [markdown]
# 1. Загрузите данные из файлов `reviews_short.csv` и `recipes_short_5.csv` в виде `pd.DataFrame`. Обратите внимание на корректное считывание столбца(ов) с индексами. Оставьте в таблице с рецептами следующие столбцы: `id, name, minutes, submitted, description, n_ingredients`

# %%
reviews = pd.read_csv(dp/'reviews_sample.csv', index_col=0)
recipes = pd.read_csv(dp/'recipes_sample.csv')
recipes = recipes.drop(columns=['n_steps', 'contributor_id'])
recipes
# Out:
#                                                name      id  minutes  \
# 0             george s at the cove  black bean soup   44123       90
# 1                healthy for them  yogurt popsicles   67664       10
# 2                      i can t believe it s spinach   38798       30
# 3                              italian  gut busters   35173       45
# 4          love is in the air  beef fondue   sauces   84797       25
# ...                                             ...     ...      ...
# 29995  zurie s holey rustic olive and cheddar bread  267661       80
# 29996          zwetschgenkuchen  bavarian plum cake  386977      240
# 29997   zwiebelkuchen   southwest german onion cake  103312       75
# 29998                                   zydeco soup  486161       60
# 29999        cookies by design   cookies on a stick  298512       29
#
#         submitted                                        description  \
# 0      2002-10-25  an original recipe created by chef scott meska...
# 1      2003-07-26  my children and their friends ask for my homem...
# 2      2002-08-29            these were so go, it surprised even me.
# 3      2002-07-27  my sister-in-law made these for us at a family...
# 4      2004-02-23  i think a fondue is a very romantic casual din...
# ...           ...                                                ...
# 29995  2007-11-25  this is based on a french recipe but i changed...
# 29996  2009-08-24  this is a traditional fresh plum cake, thought...
# 29997  2004-11-03  this is a traditional late summer early fall s...
# 29998  2012-08-29  this is a delicious soup that i originally fou...
# 29999  2008-04-15  i've heard of the 'cookies by design' company,...
#
#        n_ingredients
# 0               18.0
# 1                NaN
# 2                8.0
# 3                NaN
# 4                NaN
# ...              ...
# 29995           10.0
# 29996           11.0
# 29997            NaN
# 29998            NaN
# 29999           10.0
#
# [30000 rows x 6 columns]

# %% [markdown]
# 2. Случайным образом выберите 5% строк из каждой таблицы и сохраните две таблицы на разные листы в один файл recipes.xlsx. Дайте листам названия "Рецепты" и "Отзывы", соответствующие содержанию таблиц.

# %%
reviews_s = reviews.sample(len(reviews)//20)
reviews_s
# Out:
#             user_id  recipe_id        date  rating  \
# 614858       179104      63746  2008-06-29       2
# 266251   2001028778     107786  2016-05-28       5
# 493835       269521     287788  2008-09-05       5
# 1114011      131351     201818  2007-08-11       5
# 251614       313120     236439  2007-08-13       5
# ...             ...        ...         ...     ...
# 385256       158744      93313  2004-08-20       5
# 266227   2001151091     107786  2016-09-01       5
# 215315       449229     107008  2007-11-09       5
# 823815        37106      78814  2005-02-13       5
# 1044545      260689     164890  2008-07-28       5
#
#                                                     review
# 614858   I'm sorry to give such a low rating but someho...
# 266251                                           Best ever
# 493835   Great side dish, and cleanup is a snap! Only t...
# 1114011  great, use mushroom soup,and make same, sounds...
# 251614   Made this for supper tonight and everyone enjo...
# ...                                                    ...
# 385256   These cookies are fantastic. I used Quaker Fre...
# 266227   I was looking for an easy rib recipe for the o...
# 215315   These are fantastic!  I made them according to...
# 823815   very easy to prepare and the family really enj...
# 1044545  Very easy and tasty for a weeknight meal - a w...
#
# [6334 rows x 5 columns]

# %%
recipes_s = recipes.sample(len(recipes)//20)
recipes_s
# Out:
#                                                 name      id  minutes  \
# 15927            lemon pancakes with raspberry sauce  419114       20
# 24736                      soft chewy raisin cookies   18721       32
# 28030                      tropical fruity smoothies  227046       15
# 3281                         blomidon inn apple tart  168115      120
# 18036                   momeo s beanless spicy chili  346715       75
# ...                                              ...     ...      ...
# 16602                              lucky limey float  327259        5
# 22919      romaine salad with a creamy dill dressing  249148       10
# 14572  iron chef winner s japanese pan fried chicken   29025       30
# 19429                            orange pecan scones  200833       50
# 20117                     peach chicken spring salad  100292      210
#
#         submitted                                        description  \
# 15927  2010-04-06  got this recipe from a friend along with a mas...
# 24736  2002-02-02  best raisin cookie i've found. this recipe mak...
# 28030  2007-05-09  tastes great and it's good for you too!  perfe...
# 3281   2006-05-15  a prize winning dessert from the blomidon inn ...
# 18036  2009-01-05  this is my signature chili. hubby loves this a...
# ...           ...                                                ...
# 16602  2008-09-25  my mom used to make these on st. patrick's day...
# 22919  2007-08-27  crunchy romaine lettuce with vegetables and a ...
# 14572  2002-05-21     a recipe from katsuyo kobayashi, and her book
# 19429  2006-12-17  light and moist, these are perfect for breakfa...
# 20117  2004-09-21  preparation time includes marinating time. gri...
#
#        n_ingredients
# 15927            9.0
# 24736           13.0
# 28030            7.0
# 3281            12.0
# 18036           13.0
# ...              ...
# 16602            3.0
# 22919           13.0
# 14572            7.0
# 19429            NaN
# 20117           19.0
#
# [1500 rows x 6 columns]

# %%
writer = pd.ExcelWriter("./src/tables/recipes.xlsx", engine='xlsxwriter')
recipes_s.to_excel(writer, sheet_name='Рецепты')
reviews_s.to_excel(writer, sheet_name='Отзывы')
writer.save()
# Out:
# C:\Users\DaSh-More\AppData\Local\Temp\ipykernel_14528\1000474719.py:4: FutureWarning: save is not part of the public API, usage can give unexpected results and will be removed in a future version
#   writer.save()

# %%
pth = "./src/tables/recipes.xlsx"
wb = xw.Book(pth)
sheet = wb.sheets['Рецепты']

# %% [markdown]
# 3. Используя xlwings, добавьте на лист Рецепты столбец seconds_assign, показывающий время выполнения рецепта в секундах. Выполните задание при помощи присваивания массива значений диапазону ячеек.

# %%
sheet['H1'].value = ['seconds_assign', *
                     (recipes_s['minutes']*60).values.reshape((-1, 1))]

# %% [markdown]
# 4. Используя xlwings, добавьте на лист Рецепты столбец seconds_formula, показывающий время выполнения рецепта в секундах. Выполните задание при помощи формул Excel.

# %%
sheet[f'I1'].value = [['seconds_formula']] + \
    [[f'=D{n+2}*60'] for n in range(len(recipes_s))]

# %% [markdown]
# 5. Добавьте на лист Рецепты столбец n_reviews, содержащий кол-во отзывов для этого рецепта

# %%
ids = list(reviews_s['recipe_id'].values)
sheet['J1'].value = [['n_reviews'], *[[ids.count(i)] for i in ids]]

# %% [markdown]
# 6. Раскрасьте ячейки столбца minutes в соответствии со следующим правилом: если рецепт выполняется быстрее 5 минут, то цвет - зеленый; от 5 до 10 минут - жёлтый; и больше 10 - красный.

# %%
def recolor(sheet, cells, color, /, step=40):
    index = 0
    while True:
        n_index = None if (index + step > len(cells)) else index + step
        sheet[';'.join(cells[index:n_index])].color = color
        # print(index, n_index)
        index += step
        if n_index in (None, len(cells)):
            break

# %%
mins = recipes_s['minutes'].values

green_rows = [f'D{i}' for i in np.where(mins < 5)[0]+2]
recolor(sheet, green_rows, "#00ff00")

red_rows = [f'D{i}' for i in np.where(mins > 10)[0]+2]
recolor(sheet, red_rows, "#ff0000")

yellow_rows = [f'D{i}' for i in np.where((5 <= mins) & (mins <= 10))[0]+2]
recolor(sheet, yellow_rows, "#ffff00")

# %% [markdown]
# 7. Сделайте названия всех добавленных столбцов полужирными и выровняйте по центру ячейки.

# %%
titles = 'A1:J1'
sheet[titles].api.Font.FontStyle = 'Bold'
sheet[titles].api.VerticalAlignment = 2
sheet[titles].api.HorizontalAlignment = 3
sheet['A:J'].autofit()

# %% [markdown]
# 8. Напишите функцию validate(), которая проверяет соответствие всех строк из листа interactions следующим правилам:\
#    Рейтинг - это число от 0 до 5 включительно\
#    Соответствующий рецепт имеется на листе рецептов\
#    В случае несоответствия этим правилам, выделите строку красным цветом

# %%
def validate(sheet):
    rating = reviews_s['rating'].values
    ids_rec = recipes_s['id'].values
    ids_rev = reviews_s['recipe_id'].values

    if recol := [f'E{n+2}' for n, i in enumerate(rating) if not (0 <= i <= 5) or (ids_rev[n] not in ids_rec)]:
        recolor(sheet, recol, '#ff0000')


validate(wb.sheets['Отзывы'])
# wb.save()
