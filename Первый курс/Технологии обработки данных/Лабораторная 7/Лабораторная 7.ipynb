# %%
from sklearn.feature_extraction.text import CountVectorizer
import pymorphy2
from nltk.metrics.distance import edit_distance
from nltk import word_tokenize
from random import sample, seed
from itertools import combinations
import pandas as pd

# %% [markdown]
# 1.1 Загрузите предобработанные описания рецептов из файла preprocessed_descriptions.csv. Получите набор уникальных слов words, содержащихся в текстах описаний рецептов (воспользуйтесь word_tokenize из nltk).

# %%
words = set()
recipes = pd.read_csv("preprocessed_descriptions.csv")
for text in recipes['preprocessed_descriptions'].values:
    words |= set(word_tokenize(str(text)))
words = list(words)
words
# Out:
# ['nigella',
#  'wonky',
#  'leicester',
#  'weichuan',
#  'foggy',
#  'granary',
#  '30minute',
#  'bowls',
#  'pharmacy',
#  'plopped',
#  'ziploc',
#  'pointsserving',
#  'diptopping',
#  'teas',
#  'ham',
#  'beppo',
#  'lowering',
#  'interviewer',
#  'memorized',
#  'chickencan',
#  'boil',
#  'goblins',
#  '17415just',
#  'nuance',
#  'premixing',
#  'pangs',
#  'emits',
#  'pastel',
#  'stiffen',
#  'aussies',
#  'sheep',
#  'navratilovas',
#  'bastes',
#  'penguin',
#  '20th',
#  'oatmealtogo',
#  'crosswise',
#  'warrington',
#  'httpallrecipescomau',
#  '48',
#  'stewlike',
#  'besure',
#  'singaporean',
#  'dorowat',
#  'littleneck',
#  'ulcer1',
#  'steal',
#  'fleischmanns',
#  'marmaladesit',
#  '218699',
#  '2nds',
#  'chapman',
#  'inaccurate',
#  'fizz',
#  'vintagevictualscom',
#  'ths',
#  'heatwave',
#  'spendid',
#  'sundaetopper',
#  'madeleine',
#  'digregorio',
#  'main',
#  'skinfoil',
#  'dukka',
#  'conspired',
#  'passovers',
#  'bindor',
#  'qualifying',
# ...

# %% [markdown]
# 1.2 Сгенерируйте 5 пар случайно выбранных слов и посчитайте между ними расстояние редактирования.

# %%
seed(1223)
for a, b in combinations(sample(words, k=5), 2):
    print(a, b, edit_distance(a, b))
# Out:
# holsts adequate 7
# holsts hmmi 5
# holsts jerrys 5
# holsts kentaro 7
# adequate hmmi 8
# adequate jerrys 7
# adequate kentaro 6
# hmmi jerrys 6
# hmmi kentaro 7
# jerrys kentaro 6

# %% [markdown]
# 1.3 Напишите функцию, которая для заданного слова word возвращает k ближайших к нему слов из списка words(близость слов измеряется с помощью расстояния Левенштейна)

# %%
def nearest_words(word, k, words):
    return sorted(words, key=lambda x: edit_distance(word, x))[:k]


nearest_words('chicken', 3, words)
# Out:
# ['chicken', 'chicke', 'shicken']
