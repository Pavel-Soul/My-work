# %%
import numpy as np
import matplotlib.pyplot as plt

def f(n):
    return (-1)**n * (1+1/(2*n))**(-n)

m = [f(1)]
for i in range(2, 100000):
    m.append(f(i)+m[-1])

plt.plot(m)

# %%
f(1000)
# Out:
# 0.606606455518054

# %%
# Out:
# -0.607279309872087
