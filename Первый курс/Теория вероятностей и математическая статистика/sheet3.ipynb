# %%
import numpy as np
from itertools import permutations
import matplotlib.pyplot as plt
import random as rand

from random import randint

# %%
def graph(func, test_count=1_000_000):
    rand.seed(1223)
    results = [0]

    for _ in range(test_count):
        results.append(func() + results[-1])

    results = [el / (n+1) for n, el in enumerate(results[1:])]

    mean = sum(results)/test_count
    s = results[test_count//50:]
    k = max(s) - min(s)
    plt.ylim(mean-k, mean+k)

    real_mean = sum(results[test_count//20:]) / (test_count//20*19)

    plt.plot(results)
    plt.plot([0, test_count], [real_mean, real_mean])
    return real_mean

# %%
def A():
  return 6 in [randint(1, 6) for _ in range(4)]


graph(A)
# Out:
# 0.5173703475879114

# %%
def B():
  return (6, 6) in [(randint(1, 6), randint(1, 6)) for _ in range(24)]


graph(B)
# Out:
# 0.4910086385074185
